# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('dataImages2.csv', sep=',')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'NameImage', 'centroid-0', 'centroid-1', 'orientation',
#        'axis_major_length', 'axis_minor_length', 'bbox-0', 'bbox-1', 'bbox-2',
#        'bbox-3', 'AOL'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('NameImage', axis=1)
# df = df.drop('PESOABATE', axis=1)
# df = df.drop('RC', axis=1)
# df = df.drop('CP', axis=1)
# # df = df.drop('AOL', axis=1)
# df = df.drop('POL', axis=1)
# df = df.drop('COL', axis=1)
# df = df.drop('EGS', axis=1)
# df = df.drop('ECC', axis=1)
# df = df.drop('FAMACHA', axis=1)
# df = df.drop('CC', axis=1)
# df = df.drop('AG', axis=1)
# df = df.drop('AC', axis=1)
# df = df.drop('AP', axis=1)
# df = df.drop('CT', axis=1)
# df = df.drop('PESOVIVO', axis=1)
# df = df.drop('Profund', axis=1)

df
# Out:
#     centroid-0   centroid-1  orientation  axis_major_length  \
# 0   680.628513  1292.731301     1.185020         668.454826
# 1   647.525834  1056.260572     1.229996         598.819443
# 2   762.059051   964.658501     1.071199         813.456394
# 3   572.263991   925.967098     1.051760         583.956908
# 4   606.055707   916.184458     1.178800         678.511688
# 5   702.059787  1426.711346     1.049927         780.933016
# 6   615.209648   566.580263     1.125802         626.655174
# 7   663.807650  1118.488057     1.115004         712.900538
# 8   634.201960   907.697296     1.259028         689.596769
# 9   705.656379  1366.666840     1.173165         705.392407
# 10  844.632496  1290.729724     1.297104         817.213878
# 11  804.983574   910.158075     1.358459         876.668278
# 12  592.297993   972.949575     1.121387         592.784120
# 13  396.235865   553.045637     0.987263         500.591129
# 14  583.574600  1034.831014     1.060257         710.391821
# 15  566.657041  1135.360181     0.985720         639.248598
# 16  247.280255   627.321602     1.515774         402.318376
# 17  710.635907   561.510590     1.050686         731.181356
# 18  317.255615   482.192084    -1.503352         482.547045
# 19  321.336200   648.898534    -1.310892         454.453288
# 20  474.313709   255.953301    -1.245165         565.874672
# 21  289.825708   710.931203    -1.304173         463.360015
# 22  508.204853  1050.358930    -1.515853         554.278648
# 23  388.700681  1488.154152    -1.529057         502.518822
# 24  252.441231   480.429752    -1.339967         451.129701
# 25  292.585179   489.814548    -1.397576         521.291428
# 26  264.683325   831.630468    -1.481136         446.090856
# 27  407.093577   627.035026     1.497287         487.474229
# 28  691.472724  1410.279520     0.982297         716.358521
# 29  599.807805  1167.431714     1.111384         657.105362
# 30  694.553618  1303.336331     1.157625         824.320047
# 31  779.239046  1342.239470     1.097863         830.538950
# 32  570.838637  1138.734834     0.962748         631.680799
# 33  543.515503  1129.646867     0.855573         601.831395
# 34  634.082168  1398.498045     0.879693         768.021762
# 35  752.031534  1422.899787     1.071805         887.817478
# 36  495.058218  1130.540954     0.844399         532.595823
# 37  637.909072  1380.002543     1.084595         772.759400
# 38  737.799381  1556.308299     1.188315         808.506974
# 39  563.453040   989.267811     0.977952         660.769052
# 40  713.664675  1429.749435     1.081001         788.521376
# 41  409.640118   810.897468     1.056369         511.091724
# 42  546.123847  1189.087853     1.035949         638.155020
# 43  436.170315   669.656358     1.070145         477.946342
# 44  697.312645  1430.203920     1.002502         766.831467
# 45  455.266451   894.827970     0.969059         533.916798
#
#     axis_minor_length  bbox-0  bbox-1  bbox-2  bbox-3    AOL
# 0          285.965281     490     950     904    1563   7,92
# 1          271.271107     485     736     866    1312   6,49
# 2          322.572070     513     577    1063    1318   7,32
# 3          246.906508     387     643     812    1137   7,27
# 4          288.963727     425     572     907    1183   8,12
# 5          317.465241     438    1052    1043    1745  10,13
# 6          211.396859     447     261     826     850   7,83
# 7          290.068759     433     784     948    1412   9,56
# 8          307.124922     500     539     927    1168    8,5
# 9          270.444547     501    1017     936    1654   6,62
# 10         317.526079     646     886    1063    1650   8,61
# 11         310.900578     609     455    1049    1278   7,59
# 12         239.886307     405     680     805    1218   8,98
# 13         215.422471     256     313     651     743   9,75
# 14         261.032164     363     706     881    1316   6,34
# 15         267.433642     326     838     807    1376   10,3
# 16         180.721946     156     469     379     846   8,39
# 17         260.082055     483     212     971     889    8,5
# 18         203.005793     227     289     476     745    9,4
# 19         173.573230     203     462     464     861    6,7
# 20         264.708393     311      30     706     542   8,64
# 21         198.914257     176     524     454     938    8,2
# 22         233.031355     404     732     681    1359  10,99
# 23         143.234008     317    1221     498    1753   9,75
# 24         186.884743     164     252     399     728    8,3
# 25         183.132506     209     274     453     762    9,5
# 26         168.815656     191     619     395    1059   8,06
# 27         183.971228     314     423     556     886   10,9
# 28         261.821742     435    1096     932    1682   9,71
# 29         254.837895     413     829     840    1424   8,04
# 30         305.204463     448     885     947    1638   9,97
# 31         301.971440     510     934    1050    1675   7,08
# 32         242.272650     362     850     868    1369   5,73
# 33         222.475015     326     850     816    1329   6,78
# 34         303.071077     312    1079     933    1678   8,88
# 35         269.836400     474    1003    1049    1758    7,5
# 36         213.913219     295     901     730    1308   7,75
# 37         283.812263     389    1007     935    1686   8,61
# 38         301.943101     508    1164    1033    1886   8,01
# 39         284.284862     299     675     804    1232   8,79
# 40         275.330389     463    1047     990    1737  11,31
# 41         202.487461     254     562     613    1038  10,07
# 42         238.262272     343     890     797    1422      9
# 43         217.698731     265     447     645     858   7,74
# 44         258.312099     444    1100    1021    1712   6,81
# 45         209.987277     275     646     674    1084  10,37

# %%
# Tratar os floats que foram inseridos com virgula ao inves de ponto.

def replaceFloat(nameColumns):
    aux = [float(str(x).replace(',', '.')) for x in df[nameColumns]]
    return aux

for x in df:
    df[x] = replaceFloat(x)

df
# Out:
#     centroid-0   centroid-1  orientation  axis_major_length  \
# 0   680.628513  1292.731301     1.185020         668.454826
# 1   647.525834  1056.260572     1.229996         598.819443
# 2   762.059051   964.658501     1.071199         813.456394
# 3   572.263991   925.967098     1.051760         583.956908
# 4   606.055707   916.184458     1.178800         678.511688
# 5   702.059787  1426.711346     1.049927         780.933016
# 6   615.209648   566.580263     1.125802         626.655174
# 7   663.807650  1118.488057     1.115004         712.900538
# 8   634.201960   907.697296     1.259028         689.596769
# 9   705.656379  1366.666840     1.173165         705.392407
# 10  844.632496  1290.729724     1.297104         817.213878
# 11  804.983574   910.158075     1.358459         876.668278
# 12  592.297993   972.949575     1.121387         592.784120
# 13  396.235865   553.045637     0.987263         500.591129
# 14  583.574600  1034.831014     1.060257         710.391821
# 15  566.657041  1135.360181     0.985720         639.248598
# 16  247.280255   627.321602     1.515774         402.318376
# 17  710.635907   561.510590     1.050686         731.181356
# 30         305.204463   448.0   885.0   947.0  1638.0   9.97
# 31         301.971440   510.0   934.0  1050.0  1675.0   7.08
# 32         242.272650   362.0   850.0   868.0  1369.0   5.73
# 33         222.475015   326.0   850.0   816.0  1329.0   6.78
# 34         303.071077   312.0  1079.0   933.0  1678.0   8.88
# 35         269.836400   474.0  1003.0  1049.0  1758.0   7.50
# 36         213.913219   295.0   901.0   730.0  1308.0   7.75
# 37         283.812263   389.0  1007.0   935.0  1686.0   8.61
# 38         301.943101   508.0  1164.0  1033.0  1886.0   8.01
# 39         284.284862   299.0   675.0   804.0  1232.0   8.79
# 40         275.330389   463.0  1047.0   990.0  1737.0  11.31
# 41         202.487461   254.0   562.0   613.0  1038.0  10.07
# 42         238.262272   343.0   890.0   797.0  1422.0   9.00
# 43         217.698731   265.0   447.0   645.0   858.0   7.74
# 44         258.312099   444.0  1100.0  1021.0  1712.0   6.81
# 45         209.987277   275.0   646.0   674.0  1084.0  10.37

# %% [markdown]
# ### Ver os valores null

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum() #check for missing values
# Out:
# centroid-0           0
# centroid-1           0
# orientation          0
# axis_major_length    0
# axis_minor_length    0
# bbox-0               0
# bbox-1               0
# bbox-2               0
# bbox-3               0
# AOL                  0
# dtype: int64

# %% [markdown]
# ### Treinando o modelo

# %%
X = df.drop('AOL', axis=1)
y = df['AOL']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)

# %%
# Fit the model
model = LinearRegression()
model = model.fit(X_train, y_train)

# %%
importance = model.coef_

# %%
#histogram
plt.bar([x for x in range (len(importance))], importance)
plt.xticks([x for x in range (len(importance))], X.columns.values.tolist(), rotation=30)
plt.show()

# %%
y_test_predict = model.predict(X_test)

# %%
plt.scatter(y_test-y_test_predict,y_test_predict)
plt.show()

# %% [markdown]
# ### Result

# %%
# model evaluation for training set
y_train_predict = model.predict(X_train)

rmse_train = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2_train = r2_score(y_train, y_train_predict)

print(f"RMSE for training is {rmse_train}")
print(f"R2 score for training is {r2_train}")
# Out:
# RMSE for training is 1.1793171038552102
# R2 score for training is 0.20418222327422897

# %%
# model evaluation for training set
y_test_predict = model.predict(X_test)

rmse_test = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2_test = r2_score(y_test, y_test_predict)

print(f"RMSE for testing is {rmse_test}")
print(f"R2 score for testing is {r2_test}")
# Out:
# RMSE for testing is 1.3746448811927938
# R2 score for testing is -0.06846670789955778

# %%
print(model.intercept_)
# Out:
# 8.074127087148494

# %%
coeff_df = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                    Coefficient
# centroid-0            0.010810
# centroid-1           -0.015897
# orientation           0.191399
# axis_major_length    -0.010194
# axis_minor_length     0.000430
# bbox-0               -0.009039
# bbox-1               -0.004640
# bbox-2               -0.005709
# bbox-3                0.021867

# %%
y_pred = model.predict(X_test)

# %%
df_aux = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_aux
# Out:
#     Actual  Predicted
# 23    9.75  10.225736
# 37    8.61   8.827125
# 15   10.30   8.586306
# 6     7.83   8.256603
# 13    9.75   7.509382
# 7     9.56   8.454047
# 19    6.70   8.624082
# 9     6.62   8.705128
# 29    8.04   8.388027
# 44    6.81   7.853939

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.1580904312516842
# Mean Squared Error: 1.88964854938955
# Root Mean Squared Error: 1.3746448811927938
