# %% [markdown]
# # - First try about my project -

# %% [markdown]
# ### Importando as bibliotecas e lendo o arquivo .csv

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Dados_Ovinos.csv', sep=',')

# %%
df
# Out:
#      Rebanho Data da coleta    Animal    AOL   POL   COL   EGS  ECC PESOVIVO  \
# 0    Ricardo     23/02/2022   amarelo  10,26  2,53  5,19  4,68  NaN     47,1
# 1    Ricardo     23/02/2022  vermelho   8,71  2,07  5,13  3,71  NaN    37,35
# 2    Ricardo     23/02/2022      azul  10,01   2,4  5,19  2,82  NaN     37,3
# 3    Ricardo     23/02/2022    branco   9,55  2,42   5,6  2,63  NaN    33,55
# 4    Ricardo     23/02/2022      rosa   9,83  2,56   5,2  3,14  NaN       35
# ..       ...            ...       ...    ...   ...   ...   ...  ...      ...
# 105      CTT     04/05/2022      4445    NaN   NaN   NaN   NaN    1      NaN
# 106      CTT     04/05/2022      7906    NaN   NaN   NaN   NaN    2      NaN
# 107      CTT     04/05/2022      7997    NaN   NaN   NaN   NaN  3,5      NaN
# 108      CTT     04/05/2022      7859    NaN   NaN   NaN   NaN    3      NaN
# 109      CTT     04/05/2022      5122    NaN   NaN   NaN   NaN    1      NaN
#
#     PESOABATE     RC  FAMACHA    CC    AG    AC  AP    CT    CP  Profund
# 0        21,6  45,86      1.0  70.0  70.0  73.0 NaN  89.0  43.0      NaN
# 1        17,4  46,59      1.0  67.0  70.0  67.0 NaN  79.0  41.0      NaN
# 2        16,3  43,70      2.0  72.0  63.0  61.0 NaN  76.0  41.0      NaN
# 3        17,3  51,56      2.0  67.0  67.0  68.0 NaN  76.0  32.0      NaN
# 4          15  42,86      2.0  57.0  62.0  64.0 NaN  78.0  29.0      NaN
# ..        ...    ...      ...   ...   ...   ...  ..   ...   ...      ...
# 105       NaN    NaN      4.0   NaN   NaN   NaN NaN   NaN   NaN      NaN
# 106       NaN    NaN      4.0   NaN   NaN   NaN NaN   NaN   NaN      NaN
# 107       NaN    NaN      3.0   NaN   NaN   NaN NaN   NaN   NaN      NaN
# 108       NaN    NaN      3.0   NaN   NaN   NaN NaN   NaN   NaN      NaN
# 109       NaN    NaN      5.0   NaN   NaN   NaN NaN   NaN   NaN      NaN
#
# [110 rows x 19 columns]

# %%
df = df.drop('Rebanho', axis=1)
df = df.drop('Data da coleta', axis=1)
df = df.drop('Animal', axis=1)
df = df.drop('PESOABATE', axis=1)
df = df.drop('RC', axis=1)

df
# Out:
#        AOL   POL   COL   EGS  ECC PESOVIVO  FAMACHA    CC    AG    AC  AP  \
# 0    10,26  2,53  5,19  4,68  NaN     47,1      1.0  70.0  70.0  73.0 NaN
# 1     8,71  2,07  5,13  3,71  NaN    37,35      1.0  67.0  70.0  67.0 NaN
# 2    10,01   2,4  5,19  2,82  NaN     37,3      2.0  72.0  63.0  61.0 NaN
# 3     9,55  2,42   5,6  2,63  NaN    33,55      2.0  67.0  67.0  68.0 NaN
# 4     9,83  2,56   5,2  3,14  NaN       35      2.0  57.0  62.0  64.0 NaN
# ..     ...   ...   ...   ...  ...      ...      ...   ...   ...   ...  ..
# 105    NaN   NaN   NaN   NaN    1      NaN      4.0   NaN   NaN   NaN NaN
# 106    NaN   NaN   NaN   NaN    2      NaN      4.0   NaN   NaN   NaN NaN
# 107    NaN   NaN   NaN   NaN  3,5      NaN      3.0   NaN   NaN   NaN NaN
# 108    NaN   NaN   NaN   NaN    3      NaN      3.0   NaN   NaN   NaN NaN
# 109    NaN   NaN   NaN   NaN    1      NaN      5.0   NaN   NaN   NaN NaN
#
#        CT    CP  Profund
# 0    89.0  43.0      NaN
# 1    79.0  41.0      NaN
# 2    76.0  41.0      NaN
# 3    76.0  32.0      NaN
# 4    78.0  29.0      NaN
# ..    ...   ...      ...
# 105   NaN   NaN      NaN
# 106   NaN   NaN      NaN
# 107   NaN   NaN      NaN
# 108   NaN   NaN      NaN
# 109   NaN   NaN      NaN
#
# [110 rows x 14 columns]

# %%
# Tratar os floats que foram inseridos com virgula ao inves de ponto.

def replaceFloat(nameColumns):
    aux = [float(str(x).replace(',', '.')) for x in df[nameColumns]]
    return aux

for x in df:
    df[x] = replaceFloat(x)

df
# Out:
#        AOL   POL   COL   EGS  ECC  PESOVIVO  FAMACHA    CC    AG    AC  AP  \
# 0    10.26  2.53  5.19  4.68  NaN     47.10      1.0  70.0  70.0  73.0 NaN
# 1     8.71  2.07  5.13  3.71  NaN     37.35      1.0  67.0  70.0  67.0 NaN
# 2    10.01  2.40  5.19  2.82  NaN     37.30      2.0  72.0  63.0  61.0 NaN
# 3     9.55  2.42  5.60  2.63  NaN     33.55      2.0  67.0  67.0  68.0 NaN
# 4     9.83  2.56  5.20  3.14  NaN     35.00      2.0  57.0  62.0  64.0 NaN
# ..     ...   ...   ...   ...  ...       ...      ...   ...   ...   ...  ..
# 105    NaN   NaN   NaN   NaN  1.0       NaN      4.0   NaN   NaN   NaN NaN
# 106    NaN   NaN   NaN   NaN  2.0       NaN      4.0   NaN   NaN   NaN NaN
# 107    NaN   NaN   NaN   NaN  3.5       NaN      3.0   NaN   NaN   NaN NaN
# 108    NaN   NaN   NaN   NaN  3.0       NaN      3.0   NaN   NaN   NaN NaN
# 109    NaN   NaN   NaN   NaN  1.0       NaN      5.0   NaN   NaN   NaN NaN
#
#        CT    CP  Profund
# 0    89.0  43.0      NaN
# 1    79.0  41.0      NaN
# 2    76.0  41.0      NaN
# 3    76.0  32.0      NaN
# 4    78.0  29.0      NaN
# ..    ...   ...      ...
# 105   NaN   NaN      NaN
# 106   NaN   NaN      NaN
# 107   NaN   NaN      NaN
# 108   NaN   NaN      NaN
# 109   NaN   NaN      NaN
#
# [110 rows x 14 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Tratando alguns valores NaN
# #### Lembrar de variar os procedimentos dos valores NaN's afim de encontrar a melhor forma de trata-los

# %%
df.isnull().sum() #check for missing values
# Out:
# AOL         45
# POL         45
# COL         45
# EGS         45
# ECC         22
# PESOVIVO    38
# FAMACHA     16
# CC          38
# AG          38
# AC          38
# AP          47
# CT          38
# CP          38
# Profund     47
# dtype: int64

# %%
df = df[df['AOL'].notna()] # Deleta todas as linhas com NaN ou null na coluna AOL.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# 32  2.06  5.08  2.40  2.5     40.20      2.0  65.0  78.0  77.0  39.0  82.0
# 31  1.84  4.49  3.60  2.5     34.90      3.0  58.0  69.0  66.0  35.0  74.0
#
#       CP  Profund
# 73  40.0     31.0
# 48  39.0     33.0
# 79  42.0     31.0
# 77  36.0     29.0
# 82  40.0     33.0
# 45  27.0     25.0
# 28  38.0     30.0
# 55  37.0     29.0
# 32  35.0     38.0
# 31  31.0     31.0

# %%
print(y_train, y_test)
# Out:
# 83     7.32
# 27     8.20
# 75    10.30
# 70     6.62
# 35     9.40
# 46     8.61
# 72    10.13
# 52    10.07
# 43     8.04
# 69     7.92
# 26     8.30
# 37    10.90
# 71     6.34
# 80     9.56
# 51     9.00
# 30     8.64
# 38     8.01
# 47     5.73
# 44     7.75
# 42     8.88
# 39     7.50
# 29     9.75
# 76     9.75
# 49     8.79
# 36    11.60
# 41     7.74
# 81     8.12
# 84     8.50
# 33     8.39
# 78     7.27
# 54     7.08
# 50    10.37
# 53     6.78
# 25     8.50
# 40     9.97
# 74     7.83
# 34    10.99
# Name: AOL, dtype: float64 73     6.49
# 48    11.31
# 79     7.59
# 77     8.98
# 82     8.61
# 45     9.71
# 28     6.70
# 55     6.81
# 32     9.50
# 31     8.06
# Name: AOL, dtype: float64

# %%
# Fit the model
model = LinearRegression()
model = model.fit(X_train, y_train)

# %%
importance = model.coef_

# %%
#histogram
plt.bar([x for x in range (len(importance))], importance)
plt.xticks([x for x in range (len(importance))], X.columns.values.tolist(), rotation=30)
plt.show()

# %% [markdown]
# ### Melhores valores para apurar o AOL

# %%
X = pd.DataFrame(np.c_[df['AP'], df['Profund']], columns = ['AP', 'Profund'])
y = df['AOL']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=10)

# %%
# Fit the model
model = LinearRegression()
model = model.fit(X_train, y_train)

# %%
importance = model.coef_

# %%
#histogram
plt.bar([x for x in range (len(importance))], importance)
plt.xticks([x for x in range (len(importance))], X.columns.values.tolist(), rotation=30)
plt.show()

# %% [markdown]
# #### Avaliando o modelo

# %%
y_test_predict = model.predict(X_test)

# %%
plt.scatter(y_test-y_test_predict,y_test_predict)
plt.show()

# %% [markdown]
# #### MSE -> mean_squared_error
# #### R2 -> pontuação R2 eh o coeficiente de determinação, é outra métrica para avaliar seu modelo de forma confiável.)

# %%
# model evaluation for training set
y_train_predict = model.predict(X_train)

rmse_train = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2_train = r2_score(y_train, y_train_predict)

print(f"RMSE for training is {rmse_train}")
print(f"R2 score for training is {r2_train}")
# Out:
# RMSE for training is 1.308534336650205
# R2 score for training is 0.0698275582688761

# %%
# model evaluation for training set
y_test_predict = model.predict(X_test)

rmse_test = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2_test = r2_score(y_test, y_test_predict)

print(f"RMSE for testing is {rmse_test}")
print(f"R2 score for testing is {r2_test}")
# Out:
# RMSE for testing is 1.4562563417417789
# R2 score for testing is 0.01851333519239806
